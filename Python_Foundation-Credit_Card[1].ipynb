# %% [markdown]
# ### Importing the Datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %%
Customer = pd.read_csv(r'C:\Users\user\Desktop\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\Customer Acqusition.csv')
Spend = pd.read_csv(r'C:\Users\user\Desktop\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\spend.csv')
Repayment = pd.read_csv(r'C:\Users\user\Desktop\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\Repayment.csv')
Credit_card_data = pd.read_excel(r'C:\Users\user\Desktop\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\Credit Card Data.xlsx',sheet_name=None)

# %%
Customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        100 non-null    int64
#  1   Customer  100 non-null    object
#  2   Age       100 non-null    int64
#  3   City      100 non-null    object
#  4   Product   100 non-null    object
#  5   Limit     100 non-null    float64
#  6   Company   100 non-null    object
#  7   Segment   100 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
Customer.isna().sum()
# Out:
# No          0
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
Customer.loc[Customer.duplicated()]
# Out:
# Empty DataFrame
# Columns: [No, Customer, Age, City, Product, Limit, Company, Segment]
# Index: []

# %%
Customer
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Spend
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
Spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl No:    1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Month     1500 non-null   object
#  3   Type      1500 non-null   object
#  4   Amount    1500 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 58.7+ KB

# %%
Spend['Month'] = pd.to_datetime(Spend['Month'], format = "%d-%b-%y")

# %%
Spend.isna().sum()
# Out:
# Sl No:      0
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
Spend.loc[Spend.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sl No:, Customer, Month, Type, Amount]
# Index: []

# %%
Spend
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1 2004-01-12   JEWELLERY  485470.80
# 1          2       A1 2004-01-03       PETRO  410556.13
# 2          3       A1 2004-01-15     CLOTHES   23740.46
# 3          4       A1 2004-01-25        FOOD  484342.47
# 4          5       A1 2005-01-17      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67 2006-02-04  BUS TICKET  356872.73
# 1496    1497      A68 2006-03-25  BUS TICKET  204971.10
# 1497    1498      A69 2006-03-31  BUS TICKET   50449.44
# 1498    1499      A70 2006-03-23  BUS TICKET   80593.94
# 1499    1500      A71 2006-03-24  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
Repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
Repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SL No:      1499 non-null   float64
#  1   Customer    1500 non-null   object
#  2   Month       1500 non-null   object
#  3   Amount      1500 non-null   float64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 59.6+ KB

# %%
Repayment['Month'] = pd.to_datetime(Repayment['Month'], format = "%d-%b-%y")

# %%
Repayment.isna().sum()
# Out:
# SL No:          24
# Customer        23
# Month           23
# Amount          23
# Unnamed: 4    1523
# dtype: int64

# %%
Repayment.drop(['Unnamed: 4','SL No:'],axis = 1,inplace = True)

# %%
Repayment.dropna(axis = 0,inplace = True)

# %%
Repayment.loc[Repayment.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer, Month, Amount]
# Index: []

# %%
Repayment
# Out:
#      Customer      Month     Amount
# 0          A1 2004-01-12  495414.75
# 1          A1 2004-01-03  245899.02
# 2          A1 2004-01-15  259490.06
# 3          A1 2004-01-25  437555.12
# 4          A1 2005-01-17  165972.88
# ...       ...        ...        ...
# 1495      A67 2005-05-09   55638.77
# 1496      A68 2006-05-10  319836.49
# 1497      A69 2006-07-11  247628.45
# 1498      A70 2005-08-12  454016.51
# 1499      A71 2004-09-13   56286.33
#
# [1500 rows x 3 columns]

# %% [markdown]
# ### 1. In the above dataset,
# #### a. In case age is less than 18, replace it with mean of age values.
# #### b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
# #### (customer’s limit provided in acquisition table is the per transaction limit on his card)
# ####  c. Incase the repayment amount is more than the limit, replace the repayment with the limit

# %%
#  a. In case age is less than 18, replace it with mean of age values.

Customer['Age'] = np.where(Customer['Age']<18 , Customer['Age'].mean(),Customer['Age'])

# %%
Customer
# Out:
#      No Customer   Age        City   Product     Limit Company        Segment
# 0     1       A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3  34.0      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4  47.0      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5  56.0   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...   ...         ...       ...       ...     ...            ...
# 95   96      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
# b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
# (customer’s limit provided in acquisition table is the per transaction limit on his card)

Customer_Spend = pd.merge(Customer,Spend,on = 'Customer',how = 'inner')

# %%
Customer_Spend['Amount'] = np.where((Customer_Spend['Amount'] > Customer_Spend['Limit']),Customer_Spend['Limit']/2,Customer_Spend['Amount'])

# %%
Customer_Spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount
# 0     Self Employed       1 2004-01-12   JEWELLERY  485470.80
# ...

# %%
# c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

Customer_Repayment = pd.merge(Customer,Repayment,on = 'Customer',how='inner')

# %%
Customer_Repayment['Amount'] = np.where((Customer_Repayment['Amount'] > Customer_Repayment['Limit']),Customer_Repayment['Limit'],Customer_Repayment['Amount'])

# %%
Customer_Repayment
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment      Month     Amount
# 0     Self Employed 2004-01-12  495414.75
# 1     Self Employed 2004-01-03  245899.02
# 2     Self Employed 2004-01-15  259490.06
# ...

# %% [markdown]
# ### 2. From the above dataset create the following summaries:
# #### a. How many distinct customers exist?

# %%
Customer['Customer'].nunique()
# Out:
# 100

# %% [markdown]
# ####  b. How many distinct categories exist?

# %%
Customer_Spend['Product'].nunique()
# Out:
# 3

# %%
Customer_Repayment['Product'].nunique()
# Out:
# 3

# %% [markdown]
# #### c. What is the average monthly spend by customers?

# %%
Customer_Spend['Mon']=Customer_Spend['Month'].dt.month
Customer_Spend['Year']=Customer_Spend['Month'].dt.year

# %%
Customer_Spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount  Mon  Year
# 0     Self Employed       1 2004-01-12   JEWELLERY  485470.80    1  2004
# ...

# %%
Amount_Spend = Customer_Spend.groupby(['Customer','Month','Mon'])['Amount'].mean().reset_index()

# %%
Amount_Spend
# Out:
#      Customer      Month  Mon      Amount
# 0          A1 2004-01-03    1  410556.130
# 1          A1 2004-01-12    1  463017.010
# 2          A1 2004-01-15    1   23740.460
# 3          A1 2004-01-25    1  439656.715
# 4          A1 2004-02-05    2   52208.650
# ...       ...        ...  ...         ...
# 1252      A95 2004-01-15    1  240401.500
# 1253      A96 2004-01-25    1   54729.660
# 1254      A97 2004-01-12    1    5000.000
# 1255      A98 2004-01-03    1    5000.500
# 1256      A99 2004-01-15    1    5001.000
#
# [1257 rows x 4 columns]

# %%
Average_Monthly_Spend = Amount_Spend.groupby(['Customer','Mon'])['Amount'].mean().reset_index()

# %%
Average_Monthly_Spend
# Out:
#     Customer  Mon        Amount
# 0         A1    1  341332.87700
# 1         A1    2  138421.15125
# 2         A1    4  261649.25000
# 3         A1    5  361141.31000
# 4         A1    8  344372.10000
# ..       ...  ...           ...
# 573      A95    1  240401.50000
# 574      A96    1   54729.66000
# 575      A97    1    5000.00000
# 576      A98    1    5000.50000
# 577      A99    1    5001.00000
#
# [578 rows x 3 columns]

# %% [markdown]
# #### d. What is the average monthly repayment by customers?

# %%
Customer_Repayment['Mon'] = Customer_Repayment['Month'].dt.month
Customer_Repayment['Year'] = Customer_Repayment['Month'].dt.year

# %%
Customer_Repayment
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment      Month     Amount  Mon  Year
# 0     Self Employed 2004-01-12  495414.75    1  2004
# 1     Self Employed 2004-01-03  245899.02    1  2004
# ...

# %%
Amount_Repayment = Customer_Repayment.groupby(['Customer','Month','Mon'])['Amount'].mean().reset_index()

# %%
Amount_Repayment
# Out:
#      Customer      Month  Mon      Amount
# 0          A1 2004-01-03    1  245899.020
# 1          A1 2004-01-12    1  422930.785
# 2          A1 2004-01-15    1  356258.850
# 3          A1 2004-01-25    1  437555.120
# 4          A1 2004-02-05    2  117964.430
# ...       ...        ...  ...         ...
# 1276      A95 2004-01-15    1  369405.960
# 1277      A96 2004-01-25    1  100000.000
# 1278      A97 2004-01-12    1   10000.000
# 1279      A98 2004-01-03    1   10001.000
# 1280      A99 2004-01-15    1   10002.000
#
# [1281 rows x 4 columns]

# %%
Average_Monthly_Repayment =  Amount_Repayment.groupby(['Customer','Mon'])['Amount'].mean().reset_index()

# %%
Average_Monthly_Repayment
# Out:
#     Customer  Mon      Amount
# 0         A1    1  325723.331
# 1         A1    2  137713.785
# 2         A1    4  254474.580
# 3         A1    7  297176.740
# 4         A1    9  186427.500
# ..       ...  ...         ...
# 553      A95    1  369405.960
# 554      A96    1  100000.000
# 555      A97    1   10000.000
# 556      A98    1   10001.000
# 557      A99    1   10002.000
#
# [558 rows x 3 columns]

# %% [markdown]
# ####  e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?
# #### (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment
# #### – Monthly spend. Interest is earned only on positive profits and not on negative amounts)

# %%
Monthly_Profit = pd.merge(Average_Monthly_Spend,Average_Monthly_Repayment,left_on =['Customer','Mon'],right_on =['Customer','Mon'],how='inner')

# %%
Monthly_Profit
# Out:
#     Customer  Mon      Amount_x       Amount_y
# 0         A1    1  341332.87700  325723.331000
# 1         A1    2  138421.15125  137713.785000
# 2         A1    4  261649.25000  254474.580000
# 3         A1   11  183839.61000  285729.090000
# 4        A10    1  173828.28250  283324.721667
# ..       ...  ...           ...            ...
# 449      A95    1  240401.50000  369405.960000
# 450      A96    1   54729.66000  100000.000000
# 451      A97    1    5000.00000   10000.000000
# 452      A98    1    5000.50000   10001.000000
# 453      A99    1    5001.00000   10002.000000
#
# [454 rows x 4 columns]

# %%
Monthly_Profit['Mon_Profit'] = Monthly_Profit['Amount_y'] - Monthly_Profit['Amount_x']

# %%
Monthly_Profit
# Out:
#     Customer  Mon      Amount_x       Amount_y     Mon_Profit
# 0         A1    1  341332.87700  325723.331000  -15609.546000
# 1         A1    2  138421.15125  137713.785000    -707.366250
# 2         A1    4  261649.25000  254474.580000   -7174.670000
# 3         A1   11  183839.61000  285729.090000  101889.480000
# 4        A10    1  173828.28250  283324.721667  109496.439167
# ..       ...  ...           ...            ...            ...
# 449      A95    1  240401.50000  369405.960000  129004.460000
# 450      A96    1   54729.66000  100000.000000   45270.340000
# 451      A97    1    5000.00000   10000.000000    5000.000000
# 452      A98    1    5000.50000   10001.000000    5000.500000
# 453      A99    1    5001.00000   10002.000000    5001.000000
#
# [454 rows x 5 columns]

# %%
Monthly_Profit['Profit'] =np.where(( Monthly_Profit['Mon_Profit'] > 0),(Monthly_Profit['Mon_Profit'] * 0.029),0)

# %%
Monthly_Profit
# Out:
#     Customer  Mon      Amount_x       Amount_y     Mon_Profit       Profit
# 0         A1    1  341332.87700  325723.331000  -15609.546000     0.000000
# 1         A1    2  138421.15125  137713.785000    -707.366250     0.000000
# 2         A1    4  261649.25000  254474.580000   -7174.670000     0.000000
# 3         A1   11  183839.61000  285729.090000  101889.480000  2954.794920
# 4        A10    1  173828.28250  283324.721667  109496.439167  3175.396736
# ..       ...  ...           ...            ...            ...          ...
# 449      A95    1  240401.50000  369405.960000  129004.460000  3741.129340
# 450      A96    1   54729.66000  100000.000000   45270.340000  1312.839860
# 451      A97    1    5000.00000   10000.000000    5000.000000   145.000000
# 452      A98    1    5000.50000   10001.000000    5000.500000   145.014500
# 453      A99    1    5001.00000   10002.000000    5001.000000   145.029000
#
# [454 rows x 6 columns]

# %% [markdown]
# #### f. What are the top 5 product types?

# %%
Product_type = Customer_Spend.groupby('Type')['Amount'].sum().reset_index()

# %%
Product_type_sort = Product_type.sort_values(by = 'Amount',ascending = False)

# %%
Product_type_sort.head(5)
# Out:
#             Type       Amount
# 10         PETRO  28597384.98
# 4         CAMERA  27690738.44
# 7           FOOD  20519243.60
# 0     AIR TICKET  20155847.12
# 14  TRAIN TICKET  19995825.72

# %% [markdown]
# #### g. Which city is having maximum spend?

# %%
Customer_Spend.groupby('City')['Amount'].sum().reset_index().sort_values(by = 'Amount',ascending = False).head(1)
# Out:
#      City      Amount
# 4  COCHIN  45963513.5

# %% [markdown]
# ####  h. Which age group is spending more money?

# %%
Customer_Spend['Age_Group'] =np.where(((Customer_Spend['Age'] > 18) & (Customer_Spend['Age'] < 25)),'Youth',np.where(((Customer_Spend['Age'] >= 25) & (Customer_Spend['Age'] < 60)),'Adult','Senior') )

# %%
Customer_Spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount  Mon  Year  \
# 0     Self Employed       1 2004-01-12   JEWELLERY  485470.80    1  2004
# ...

# %%
Customer_Spend.groupby('Age_Group')['Amount'].sum().reset_index().sort_values(by = 'Amount',ascending = False)
# Out:
#   Age_Group        Amount
# 0     Adult  1.557433e+08
# 1    Senior  4.935734e+07
# 2     Youth  1.468050e+07

# %% [markdown]
# #### i. Who are the top 10 customers in terms of repayment?

# %%
Customer_Repayment.groupby('Customer')['Amount'].sum().reset_index().sort_values(by ='Amount',ascending = False).head(10)
# Out:
#    Customer       Amount
# 58      A61  10539142.91
# 57      A60   9876290.74
# 5       A13   9572000.66
# 38      A43   8489871.46
# 40      A45   8448334.87
# 4       A12   8334760.16
# 6       A14   7943268.63
# 39      A44   7744730.12
# 33      A39   7622483.30
# 37      A42   7615460.86

# %% [markdown]
# ### 3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.
# .

# %%
Citywise_Spend = Customer_Spend.groupby(['City','Year','Product'])['Amount'].sum().reset_index()

# %%
Citywise_Spend
# Out:
#           City  Year   Product       Amount
# 0    BANGALORE  2004      Gold   9289878.54
# 1    BANGALORE  2004  Platimum   1112732.30
# 2    BANGALORE  2004    Silver   1291852.58
# 3    BANGALORE  2005      Gold  12892362.99
# 4    BANGALORE  2005  Platimum    912284.97
# ..         ...   ...       ...          ...
# 67  TRIVANDRUM  2005  Platimum   3601443.30
# 68  TRIVANDRUM  2005    Silver    269912.99
# 69  TRIVANDRUM  2006      Gold   2735710.87
# 70  TRIVANDRUM  2006  Platimum   2147403.75
# 71  TRIVANDRUM  2006    Silver    555862.12
#
# [72 rows x 4 columns]

# %%
Citywise_Graph = pd.pivot_table(data=Citywise_Spend,index='City',columns='Year',values='Amount',aggfunc='sum')

# %%
Citywise_Graph.plot(kind='bar')
plt.title("Yearly Spend Product")
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# ### 4. Create graphs for
# #### a. Monthly comparison of total spends, city wise

# %%
Comparison = pd.pivot_table(data=Customer_Spend,index='City',columns='Mon',values='Amount',aggfunc='sum')

# %%
Comparison.plot(kind='bar')
plt.title("Citywise_Monthly_Spend")
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# #### b. Comparison of yearly spend on air tickets

# %%
Customer_Spend_Airticket = Customer_Spend.loc[Customer_Spend['Type']=='AIR TICKET']

# %%
Yearly_Spend = pd.pivot_table(data=Customer_Spend_Airticket,index='Type',columns='Year',values='Amount',aggfunc='sum')

# %%
Yearly_Spend.plot(kind='bar')
plt.title(" Airtickets Yearly Spend")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# ####  c. Comparison of monthly spend for each product (look for any seasonality  that exists in terms of spend)
# )

# %%
Customer_Spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount  Mon  Year  \
# 0     Self Employed       1 2004-01-12   JEWELLERY  485470.80    1  2004
# ...

# %%
Monthly_Spend = pd.pivot_table(data=Customer_Spend,index='Product',columns='Mon',values='Amount',aggfunc='sum')

# %%
Monthly_Spend.plot(kind='bar')
plt.title(" Products Monthly Spend")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# ### 5. Write user defined PYTHON function to perform the following analysis:
# ##### You need to find top 10 customers for each city in terms of their repayment amount by
# ##### different products and by different time periods i.e. year or month. The user should be able
# ##### to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the
# ##### function should automatically take these inputs while identifying the top 10 customers.

# %%
def top_Customers(Products,Time_Periods):
    Products = input("Choose any one from Gold,Silver,Platimum :")
    Time_Periods = input("Choose Mon or Year")
    if Time_Periods == 'Year':
            return Customer_Repayment.loc[Customer_Repayment['Product'] == Products].groupby(['Customer','City','Product','Year'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending =False).head(10)
     
    else:
            return Customer_Repayment.loc[Customer_Repayment['Product'] == Products].groupby(['Customer','City','Product','Mon'])['Amount'].sum().reset_index().sort_values(by='Amount',ascending =False).head(10)

# %%
top_Customers('Silver','Mon')
# Out:
# Choose any one from Gold,Silver,Platimum : Silver
# Choose Mon or Year Mon
#     Customer        City Product  Mon     Amount
# 16       A22      BOMBAY  Silver    1  900000.00
# 57       A46       PATNA  Silver    1  713614.32
# 107       A8       PATNA  Silver    1  600012.00
# 85        A6       DELHI  Silver    1  600000.00
# 3        A18   BANGALORE  Silver    3  600000.00
# 93        A7      COCHIN  Silver    1  594009.28
# 47       A25      COCHIN  Silver    1  586332.08
# 67       A57  TRIVANDRUM  Silver    3  578549.42
# 51       A25      COCHIN  Silver    5  572616.74
# 58       A46       PATNA  Silver    2  544231.79
